# %%
import pandas as pd

# %%
df = pd.read_csv("WhatsApp Chat with Ravi Sir.txt",header=None,error_bad_lines=False,encoding='utf8')

# %%
df
# Out:
#             0                                                  1  \
# 0    11/08/22   10:09 am - Messages and calls are end-to-end ...
# 1    24/08/22      6:51 pm - udhayamechengineer: <Media omitted>
# 2    27/08/22                 2:05 pm - Ravi Sir: Okay noted but
# 3    28/08/22                5:37 pm - Ravi Sir: <Media omitted>
# 4    01/09/22   9:31 am - udhayamechengineer: Urgent requirem...
# ..        ...                                                ...
# 355  12/12/23      1:14 pm - udhayamechengineer: <Media omitted>
# 356  12/12/23      1:14 pm - udhayamechengineer: <Media omitted>
# 357  12/12/23   1:14 pm - udhayamechengineer: For SFD 1A driv...
# 358  14/12/23     11:35 am - udhayamechengineer: <Media omitted>
# 359  14/12/23                            11:46 am - Ravi Sir: 👍🏻
#
#                       2                                                3
# 0     not even WhatsApp   can read or listen to them. Tap to learn more.
# 1                   NaN                                              NaN
# 2                   NaN                                              NaN
# 3                   NaN                                              NaN
# 4                   NaN                                              NaN
# ..                  ...                                              ...
# 355                 NaN                                              NaN
# 356                 NaN                                              NaN
# 357                 NaN                                              NaN
# 358                 NaN                                              NaN
# 359                 NaN                                              NaN
#
# [360 rows x 4 columns]

# %%
# to delet the column 2,3

# Display the column names
print("Column names:")
print(df.columns)

# Display the original DataFrame (first few rows for inspection)
print("Original DataFrame:")
print(df.head())

# Assuming the actual column names are '2' and '3' (as strings)
# If they are integers, you should use integers instead
columns_to_delete = [2, 3]

# Check if columns exist and delete them
columns_to_delete = [col for col in columns_to_delete if col in df.columns]
df.drop(columns=columns_to_delete, inplace=True)
print(df.head())
# Out:
# Column names:
# Int64Index([0, 1, 2, 3], dtype='int64')
# Original DataFrame:
#           0                                                  1  \
# 0  11/08/22   10:09 am - Messages and calls are end-to-end ...
# 1  24/08/22      6:51 pm - udhayamechengineer: <Media omitted>
# 2  27/08/22                 2:05 pm - Ravi Sir: Okay noted but
# 3  28/08/22                5:37 pm - Ravi Sir: <Media omitted>
# 4  01/09/22   9:31 am - udhayamechengineer: Urgent requirem...
#
#                     2                                                3
# 0   not even WhatsApp   can read or listen to them. Tap to learn more.
# 1                 NaN                                              NaN
# 2                 NaN                                              NaN
# 3                 NaN                                              NaN
# 4                 NaN                                              NaN
#           0                                                  1
# 0  11/08/22   10:09 am - Messages and calls are end-to-end ...
# 1  24/08/22      6:51 pm - udhayamechengineer: <Media omitted>
# 2  27/08/22                 2:05 pm - Ravi Sir: Okay noted but
# 3  28/08/22                5:37 pm - Ravi Sir: <Media omitted>
# 4  01/09/22   9:31 am - udhayamechengineer: Urgent requirem...

# %%
df.columns=['Date','Chat']
Message=df["Chat"].str.split("-",n=1,expand=True)
df["Time"]=Message[0]
Message1=Message[1].str.split(":",n=1,expand=True)
df["Name"]=Message1[0]
df["Chat"]=Message1[1]
df=df[["Date","Time","Name","Chat"]]
df
# Out:
#          Date        Time                                               Name  \
# 0    11/08/22   10:09 am    Messages and calls are end-to-end encrypted. ...
# 1    24/08/22    6:51 pm                                  udhayamechengineer
# 2    27/08/22    2:05 pm                                            Ravi Sir
# 3    28/08/22    5:37 pm                                            Ravi Sir
# 4    01/09/22    9:31 am                                  udhayamechengineer
# ..        ...         ...                                                ...
# 355  12/12/23    1:14 pm                                  udhayamechengineer
# 356  12/12/23    1:14 pm                                  udhayamechengineer
# 357  12/12/23    1:14 pm                                  udhayamechengineer
# 358  14/12/23   11:35 am                                  udhayamechengineer
# 359  14/12/23   11:46 am                                            Ravi Sir
#
#                          Chat
# 0                        None
# 1             <Media omitted>
# 2              Okay noted but
# 3             <Media omitted>
# 4      Urgent requirement sir
# ..                        ...
# 355           <Media omitted>
# 356           <Media omitted>
# 357   For SFD 1A drive pulley
# 358           <Media omitted>
# 359                        👍🏻
#
# [360 rows x 4 columns]

# %%
#to delete the first row for unknown data
df = df.iloc[1:]

# Optionally, reset the index if needed
df.reset_index(drop=True, inplace=True)
df
# Out:
#          Date        Time                 Name  \
# 0    24/08/22    6:51 pm    udhayamechengineer
# 1    27/08/22    2:05 pm              Ravi Sir
# 2    28/08/22    5:37 pm              Ravi Sir
# 3    01/09/22    9:31 am    udhayamechengineer
# 4    02/09/22    8:38 pm    udhayamechengineer
# ..        ...         ...                  ...
# 354  12/12/23    1:14 pm    udhayamechengineer
# 355  12/12/23    1:14 pm    udhayamechengineer
# 356  12/12/23    1:14 pm    udhayamechengineer
# 357  14/12/23   11:35 am    udhayamechengineer
# 358  14/12/23   11:46 am              Ravi Sir
#
#                                      Chat
# 0                         <Media omitted>
# 1                          Okay noted but
# 2                         <Media omitted>
# 3                  Urgent requirement sir
# 4     Crane Velu Anna.vcf (file attached)
# ..                                    ...
# 354                       <Media omitted>
# 355                       <Media omitted>
# 356               For SFD 1A drive pulley
# 357                       <Media omitted>
# 358                                    👍🏻
#
# [359 rows x 4 columns]

# %%
print(df.dtypes)
print(df.head(10))
# Out:
# Date    object
# Time    object
# Name    object
# Chat    object
# dtype: object
#        Date        Time                 Name  \
# 0  24/08/22    6:51 pm    udhayamechengineer
# 1  27/08/22    2:05 pm              Ravi Sir
# 2  28/08/22    5:37 pm              Ravi Sir
# 3  01/09/22    9:31 am    udhayamechengineer
# 4  02/09/22    8:38 pm    udhayamechengineer
# 5  03/09/22    7:23 am              Ravi Sir
# 6  03/09/22    7:24 am    udhayamechengineer
# 7  08/09/22    1:23 pm    udhayamechengineer
# 8  08/09/22    1:24 pm    udhayamechengineer
# 9  24/09/22   10:05 pm    udhayamechengineer
#
#                                    Chat
# 0                       <Media omitted>
# 1                        Okay noted but
# 2                       <Media omitted>
# 3                Urgent requirement sir
# 4   Crane Velu Anna.vcf (file attached)
# 5                       <Media omitted>
# 6                                Ok sir
# 7                       <Media omitted>
# 8                       <Media omitted>
# 9                       <Media omitted>

# %%
import pandas as pd
import numpy as np
import itertools
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, HashingVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
import matplotlib.pyplot as plt
# Out:
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\sklearn\feature_extraction\image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\sklearn\linear_model\least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\sklearn\linear_model\least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\sklearn\linear_model\least_angle.py:284: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_Gram=True, verbose=0,
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\sklearn\linear_model\least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\sklearn\linear_model\least_angle.py:1101: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\sklearn\linear_model\least_angle.py:1127: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\sklearn\linear_model\least_angle.py:1362: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\sklearn\linear_model\least_angle.py:1602: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\sklearn\linear_model\least_angle.py:1738: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
dataset=df

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download the VADER lexicon
nltk.download('vader_lexicon')

# Initialize the sentiment analyzer
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\udhaya\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
sid = SentimentIntensityAnalyzer()

# %%
senti=sid.polarity_scores(dataset['Chat'][4])
senti
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
def sentimentalAnalysis(data,columnname):
        
        #downloading vader_lexicon for the process
        import matplotlib.pyplot as plt
        import seaborn as sns
        "Importing Necessary Packeage"
        from nltk.sentiment.vader import SentimentIntensityAnalyzer
        sid = SentimentIntensityAnalyzer()
        
        "Deleting null pr empty value"
        data.dropna(inplace=True)
        
        "Checking for a comment"
        #sid.polarity_scores(data[columnname][93])
        
        "Creating respective columns"
        
        data['scores'] = data[columnname].apply(lambda commentText: sid.polarity_scores(commentText))
        data['compound']  = data['scores'].apply(lambda score_dict: score_dict['compound'])
        data['Negtive']  = data['scores'].apply(lambda score_dict: score_dict['neg'])
        data['Postive']  = data['scores'].apply(lambda score_dict: score_dict['pos'])
        data['Neutral']  = data['scores'].apply(lambda score_dict: score_dict['neu'])
        
        "Creating final pos or neg using compound score"
        data['comp_score'] = data['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
        plt.clf()
        #comp=sns.countplot(x = 'comp_score', hue = 'Name', data = data, palette = 'magma')
        #comp.figure.savefig("date_charts.png")
        "Checking how many pos and neg"
        posneg=pd.DataFrame(data['comp_score'].value_counts())
        return posneg,data

# %%
pos,data_Senti=sentimentalAnalysis(dataset,columnname='Chat')
# Out:
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_Senti
# Out:
#          Date        Time                 Name  \
# 0    24/08/22    6:51 pm    udhayamechengineer
# 1    27/08/22    2:05 pm              Ravi Sir
# 2    28/08/22    5:37 pm              Ravi Sir
# 3    01/09/22    9:31 am    udhayamechengineer
# 4    02/09/22    8:38 pm    udhayamechengineer
# ..        ...         ...                  ...
# 354  12/12/23    1:14 pm    udhayamechengineer
# 355  12/12/23    1:14 pm    udhayamechengineer
# 356  12/12/23    1:14 pm    udhayamechengineer
# 357  14/12/23   11:35 am    udhayamechengineer
# 358  14/12/23   11:46 am              Ravi Sir
#
#                                      Chat  \
# 0                         <Media omitted>
# 1                          Okay noted but
# 2                         <Media omitted>
# 3                  Urgent requirement sir
# 4     Crane Velu Anna.vcf (file attached)
# ..                                    ...
# 354                       <Media omitted>
# 355                       <Media omitted>
# 356               For SFD 1A drive pulley
# 357                       <Media omitted>
# 358                                    👍🏻
#
#                                                 scores  compound  Negtive  \
# 0    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 1    {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compou...    0.1154      0.0
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 3    {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'comp...    0.2023      0.0
# 4    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# ..                                                 ...       ...      ...
# 354  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 355  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 356  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 357  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 358  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
#
#      Postive  Neutral comp_score
# 0      0.000    1.000        pos
# 1      0.420    0.580        pos
# 2      0.000    1.000        pos
# 3      0.474    0.526        pos
# 4      0.000    1.000        pos
# ..       ...      ...        ...
# 354    0.000    1.000        pos
# 355    0.000    1.000        pos
# 356    0.000    1.000        pos
# 357    0.000    1.000        pos
# 358    0.000    1.000        pos
#
# [359 rows x 10 columns]

# %%
pos
# Out:
#      comp_score
# pos         351
# neg           8

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(max_df=0.95,min_df=2,stop_words='english')
dtm=tfidf.fit_transform(df["Chat"])

# %%
from sklearn.decomposition import NMF
nmf_model=NMF(n_components=5,random_state=42)
nmf_model.fit(dtm)
# Out:
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\sklearn\decomposition\online_lda.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#     n_components=5, random_state=42, shuffle=False, solver='cd', tol=0.0001,
#     verbose=0)

# %%
for index,topic in enumerate(nmf_model.components_):
    results=([tfidf.get_feature_names()[i] for i in topic.argsort()[-10:]])
    print(results)
# Out:
# ['deleted', 'discuss', 'drive', 'echs', 'eds', 'engineering', 'gearbox', 'works', 'omitted', 'media']
# ['deleted', 'discuss', 'drive', 'echs', 'eds', 'conveyor', 'works', 'noted', 'sir', 'ok']
# ['deleted', 'discuss', 'drive', 'echs', 'eds', 'conveyor', 'check', 'engineering', 'good', 'okay']
# ['drive', 'stacker', '1b', 'eds', '52', 'mm', 'pump', 'thank', 'work', 'sir']
# ['update', 'okay', 'pvt', 'chennai', 'works', 'radha', 'echs', 'engineering', 'check', 'noted']

# %%
topic_results=nmf_model.transform(dtm)
df["Topic"]=topic_results.argmax(axis=1)
df
# Out:
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Date        Time                 Name  \
# 0    24/08/22    6:51 pm    udhayamechengineer
# 1    27/08/22    2:05 pm              Ravi Sir
# 2    28/08/22    5:37 pm              Ravi Sir
# 3    01/09/22    9:31 am    udhayamechengineer
# 4    02/09/22    8:38 pm    udhayamechengineer
# ..        ...         ...                  ...
# 354  12/12/23    1:14 pm    udhayamechengineer
# 355  12/12/23    1:14 pm    udhayamechengineer
# 356  12/12/23    1:14 pm    udhayamechengineer
# 357  14/12/23   11:35 am    udhayamechengineer
# 358  14/12/23   11:46 am              Ravi Sir
#
#                                      Chat  \
# 0                         <Media omitted>
# 1                          Okay noted but
# 2                         <Media omitted>
# 3                  Urgent requirement sir
# 4     Crane Velu Anna.vcf (file attached)
# ..                                    ...
# 354                       <Media omitted>
# 355                       <Media omitted>
# 356               For SFD 1A drive pulley
# 357                       <Media omitted>
# 358                                    👍🏻
#
#                                                 scores  compound  Negtive  \
# 0    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 1    {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compou...    0.1154      0.0
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 3    {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'comp...    0.2023      0.0
# 4    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# ..                                                 ...       ...      ...
# 354  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 355  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 356  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 357  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 358  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
#
#      Postive  Neutral comp_score  Topic
# 0      0.000    1.000        pos      0
# 1      0.420    0.580        pos      2
# 2      0.000    1.000        pos      0
# 3      0.474    0.526        pos      3
# 4      0.000    1.000        pos      4
# ..       ...      ...        ...    ...
# 354    0.000    1.000        pos      0
# 355    0.000    1.000        pos      0
# 356    0.000    1.000        pos      3
# 357    0.000    1.000        pos      0
# 358    0.000    1.000        pos      0
#
# [359 rows x 11 columns]

# %%
df["Topic"].value_counts()
# Out:
# 0    277
# 3     38
# 1     18
# 4     14
# 2     12
# Name: Topic, dtype: int64

# %%
#pip install wordCloud

# %%
dataset=df
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk
import matplotlib.pyplot as plt
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\udhaya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
comment_words = []
stoplist = stopwords.words('english')
stoplist.extend(['omitted', 'voice','missed','call','video','deleted','media','message'])
wordcloudss="This function saves image"
dataset.index=range(dataset.shape[0])
for i in range(1,len(dataset)): 
    comment_words.append(dataset['Chat'][i])
    vv=" ".join(comment_words)          
    wordcloud = WordCloud(width = 800, height = 800, 
                                background_color ='white', 
                                      stopwords = stoplist, 
                                      min_font_size = 10).generate(vv)         
plt.figure(figsize = (9, 7), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.savefig('wordcloud.PNG')
plt.show() 
print("Successfully created")
wordcloudss="This function saves image"
# Out:
# Successfully created
