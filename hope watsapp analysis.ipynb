# %%
import pandas as pd

# %%
df = pd.read_csv("mabel.txt",header=None,error_bad_lines=False,encoding='utf8')
# Out:
# b'Skipping line 23: expected 2 fields, saw 6\nSkipping line 44: expected 2 fields, saw 3\n'

# %%
# to delet the column 2,3

# Display the column names
print("Column names:")
print(df.columns)

# Display the original DataFrame (first few rows for inspection)
print("Original DataFrame:")
print(df.head())

# Assuming the actual column names are '2' and '3' (as strings)
# If they are integers, you should use integers instead
columns_to_delete = [2, 3]

# Check if columns exist and delete them
columns_to_delete = [col for col in columns_to_delete if col in df.columns]
df.drop(columns=columns_to_delete, inplace=True)
print(df.head())
# Out:
# Column names:
# Int64Index([0, 1], dtype='int64')
# Original DataFrame:
#           0                                                  1
# 0  05/12/19   1:42 pm - Messages to this chat and calls are...
# 1  05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...
# 2  05/12/19   1:42 pm - Mabel Infoziant: What’s your full name
# 3  05/12/19                      1:42 pm - AR❤: Ramisha Rani K
# 4  05/12/19                      1:42 pm - Mabel Infoziant: Ok
#           0                                                  1
# 0  05/12/19   1:42 pm - Messages to this chat and calls are...
# 1  05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...
# 2  05/12/19   1:42 pm - Mabel Infoziant: What’s your full name
# 3  05/12/19                      1:42 pm - AR❤: Ramisha Rani K
# 4  05/12/19                      1:42 pm - Mabel Infoziant: Ok

# %%
df.columns=['Date','Chat']
Message=df["Chat"].str.split("-",n=1,expand=True)
df["Time"]=Message[0]
Message1=Message[1].str.split(":",n=1,expand=True)
df["Name"]=Message1[0]
df["Chat"]=Message1[1]
df=df[["Date","Time","Name","Chat"]]
df
# Out:
#         Date        Time                                               Name  \
# 0   05/12/19    1:42 pm    Messages to this chat and calls are now secur...
# 1   05/12/19    1:42 pm                                     Mabel Infoziant
# 2   05/12/19    1:42 pm                                     Mabel Infoziant
# 3   05/12/19    1:42 pm                                                 AR❤
# 4   05/12/19    1:42 pm                                     Mabel Infoziant
# 5   05/12/19    1:42 pm                                     Mabel Infoziant
# 6   05/12/19    1:43 pm                                     Mabel Infoziant
# 7   05/12/19    1:43 pm                                                 AR❤
# 8   05/12/19    1:43 pm                                     Mabel Infoziant
# 9   05/12/19    1:43 pm                                                 AR❤
# 10  05/12/19    1:43 pm                                     Mabel Infoziant
# 11  05/12/19    1:43 pm                                     Mabel Infoziant
# 12  05/12/19    1:44 pm                                                 AR❤
# 13  05/12/19    1:45 pm                                                 AR❤
# 14  05/12/19    1:48 pm                                     Mabel Infoziant
# 15  05/12/19    1:48 pm                                     Mabel Infoziant
# 16  05/12/19    1:49 pm                                                 AR❤
# 17  05/12/19    2:00 pm                                                 AR❤
# 18  05/12/19    2:04 pm                                     Mabel Infoziant
# 19  05/12/19    2:04 pm                                     Mabel Infoziant
# 20  05/12/19    2:06 pm                                                 AR❤
# 21  05/12/19    2:07 pm                                                 AR❤
# 22  05/12/19    4:44 pm                                     Mabel Infoziant
# 23  05/12/19    4:48 pm                                                 AR❤
# 24  05/12/19    8:07 pm                                                 AR❤
# 25  08/12/19   10:45 pm                                     Mabel Infoziant
# 26  08/12/19   11:52 pm                                                 AR❤
# 27  08/12/19   11:55 pm                                                 AR❤
# 28  09/12/19   12:09 pm                                                 AR❤
# 29  09/12/19   12:13 pm                                     Mabel Infoziant
# 30  09/12/19   12:23 pm                                     Mabel Infoziant
# 31  09/12/19   12:25 pm                                                 AR❤
# 32  09/12/19   12:26 pm                                                 AR❤
# 33  09/12/19   12:26 pm                                                 AR❤
# 34  09/12/19   12:28 pm                                                 AR❤
# 35  09/12/19   12:28 pm                                                 AR❤
# 36  09/12/19   12:29 pm                                                 AR❤
# 37  09/12/19   12:41 pm                                     Mabel Infoziant
# 38  09/12/19   12:42 pm                                                 AR❤
# 39  10/12/19    7:59 am                                     Mabel Infoziant
# 40  10/12/19    8:00 am                                     Mabel Infoziant
# 41  10/12/19    8:55 am                                                 AR❤
# 42  12/12/19    2:26 pm                                     Mabel Infoziant
# 43  15/12/19    8:22 pm                                                 AR❤
# 44  15/12/19    8:40 pm                                     Mabel Infoziant
# 45  15/12/19    8:40 pm                                                 AR❤
# 46  18/12/19    3:09 pm                                                 AR❤
# 47  18/12/19    3:09 pm                                                 AR❤
# 48  18/12/19    3:11 pm                                     Mabel Infoziant
# 49  18/12/19    3:11 pm                                     Mabel Infoziant
# 50  18/12/19    3:12 pm                                                 AR❤
#
#                                                  Chat
# 0                                                None
# 1                      Hi this is Mabel we just spoke
# 2                               What’s your full name
# 3                                      Ramisha Rani K
# 4                                                  Ok
# 5                              ramisharanik@gmail.com
# 6                                      Your email Id?
# 7                                             Yes Mam
# 8      I will send 2 abstracts for u to start working
# 9                                            Yeah mam
# 10                   Give me the list that u have too
# 11   Send me cbe office address and phone number I...
# 12    Yeah Mam within Evening I will forward you mam.
# 13   Tomorrow I have to visit the office.yet not I...
# 14                                                 ok
# 15   send the details of office location once u ge...
# 16   Sure mam. Soon I will share details with you mam
# 17   I have read the Abstract mam. We can do mam. ...
# 18   I think Vignesh has the data set will ask him...
# 19                          I have sent the abstracts
# 20                                             Ok mam
# 21   I have read both the abstract mam. We can do ...
# 22   Yes we need to ya about amount and all other ...
# 23                                          Sure mam.
# 24                                  Shall I call mam?
# 25         Hi I was at church couldn’t take your call
# 26                                         It's k mam
# 27   Just to know the tomorrow plan mam.will see t...
# 28                    Mam can u send Vignesh number??
# 29           Vignesh ML Infoziant.vcf (file attached)
# 30                           I was in a meeting sorry
# 31                                    Can I cal u mam
# 32   Waiting for u r finalization of rates for our...
# 33   If we finiliaze I can work with full involvem...
# 34   So what ever may be ..if you think your are c...
# 35                           You deleted this message
# 36                                     Do the needful
# 37   No ma please hold I am in a hot meeting with ...
# 38                                     Ok mam thank u
# 39   Ramisha we need to talk today i will call u a...
# 40     Be ready to discuss about the ML titles u have
# 41                                           Okay mam
# 42                                                 ok
# 43                                    Mam are u free?
# 44   Am at church can call very late or tomorrow only
# 45   Kk mam. I will ask Arun brother. Small doubt ...
# 46                                             Hi mam
# 47                                   Any updates mam?
# 48     U might have to start on the WhatsApp analysis
# 49            There is one project that got committed
# 50                                           Kk mam👍🏻

# %%
#to delete the first row for unknown data
df = df.iloc[1:]

# Optionally, reset the index if needed
df.reset_index(drop=True, inplace=True)
df
# Out:
#         Date        Time              Name  \
# 0   05/12/19    1:42 pm    Mabel Infoziant
# 1   05/12/19    1:42 pm                AR❤
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm    Mabel Infoziant
# 4   05/12/19    1:43 pm    Mabel Infoziant
# 5   05/12/19    1:43 pm                AR❤
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm    Mabel Infoziant
# 10  05/12/19    1:44 pm                AR❤
# 11  05/12/19    1:45 pm                AR❤
# 12  05/12/19    1:48 pm    Mabel Infoziant
# 13  05/12/19    1:48 pm    Mabel Infoziant
# 14  05/12/19    1:49 pm                AR❤
# 15  05/12/19    2:00 pm                AR❤
# 16  05/12/19    2:04 pm    Mabel Infoziant
# 17  05/12/19    2:04 pm    Mabel Infoziant
# 18  05/12/19    2:06 pm                AR❤
# 19  05/12/19    2:07 pm                AR❤
# 20  05/12/19    4:44 pm    Mabel Infoziant
# 21  05/12/19    4:48 pm                AR❤
# 22  05/12/19    8:07 pm                AR❤
# 23  08/12/19   10:45 pm    Mabel Infoziant
# 24  08/12/19   11:52 pm                AR❤
# 25  08/12/19   11:55 pm                AR❤
# 26  09/12/19   12:09 pm                AR❤
# 27  09/12/19   12:13 pm    Mabel Infoziant
# 28  09/12/19   12:23 pm    Mabel Infoziant
# 29  09/12/19   12:25 pm                AR❤
# 30  09/12/19   12:26 pm                AR❤
# 31  09/12/19   12:26 pm                AR❤
# 32  09/12/19   12:28 pm                AR❤
# 33  09/12/19   12:28 pm                AR❤
# 34  09/12/19   12:29 pm                AR❤
# 35  09/12/19   12:41 pm    Mabel Infoziant
# 36  09/12/19   12:42 pm                AR❤
# 37  10/12/19    7:59 am    Mabel Infoziant
# 38  10/12/19    8:00 am    Mabel Infoziant
# 39  10/12/19    8:55 am                AR❤
# 40  12/12/19    2:26 pm    Mabel Infoziant
# 41  15/12/19    8:22 pm                AR❤
# 42  15/12/19    8:40 pm    Mabel Infoziant
# 43  15/12/19    8:40 pm                AR❤
# 44  18/12/19    3:09 pm                AR❤
# 45  18/12/19    3:09 pm                AR❤
# 46  18/12/19    3:11 pm    Mabel Infoziant
# 47  18/12/19    3:11 pm    Mabel Infoziant
# 48  18/12/19    3:12 pm                AR❤
#
#                                                  Chat
# 0                               What’s your full name
# 1                                      Ramisha Rani K
# 2                                                  Ok
# 3                              ramisharanik@gmail.com
# 4                                      Your email Id?
# 5                                             Yes Mam
# 6      I will send 2 abstracts for u to start working
# 7                                            Yeah mam
# 8                    Give me the list that u have too
# 9    Send me cbe office address and phone number I...
# 10    Yeah Mam within Evening I will forward you mam.
# 11   Tomorrow I have to visit the office.yet not I...
# 12                                                 ok
# 13   send the details of office location once u ge...
# 14   Sure mam. Soon I will share details with you mam
# 15   I have read the Abstract mam. We can do mam. ...
# 16   I think Vignesh has the data set will ask him...
# 17                          I have sent the abstracts
# 18                                             Ok mam
# 19   I have read both the abstract mam. We can do ...
# 20   Yes we need to ya about amount and all other ...
# 21                                          Sure mam.
# 22                                  Shall I call mam?
# 23         Hi I was at church couldn’t take your call
# 24                                         It's k mam
# 25   Just to know the tomorrow plan mam.will see t...
# 26                    Mam can u send Vignesh number??
# 27           Vignesh ML Infoziant.vcf (file attached)
# 28                           I was in a meeting sorry
# 29                                    Can I cal u mam
# 30   Waiting for u r finalization of rates for our...
# 31   If we finiliaze I can work with full involvem...
# 32   So what ever may be ..if you think your are c...
# 33                           You deleted this message
# 34                                     Do the needful
# 35   No ma please hold I am in a hot meeting with ...
# 36                                     Ok mam thank u
# 37   Ramisha we need to talk today i will call u a...
# 38     Be ready to discuss about the ML titles u have
# 39                                           Okay mam
# 40                                                 ok
# 41                                    Mam are u free?
# 42   Am at church can call very late or tomorrow only
# 43   Kk mam. I will ask Arun brother. Small doubt ...
# 44                                             Hi mam
# 45                                   Any updates mam?
# 46     U might have to start on the WhatsApp analysis
# 47            There is one project that got committed
# 48                                           Kk mam👍🏻

# %% [markdown]
# # #most talkative and less talkative

# %%
#most talkative and less talkative 
#Step 1: Clean up 'Date' and 'Time' columns
df['Date'] = df['Date'].str.strip()
df['Time'] = df['Time'].str.strip()

# Convert 'Date' and 'Time' columns to datetime format
df['DateTime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'], format='%d/%m/%y %I:%M %p')

# Step 2: Identify the most talkative and least talkative participants
message_counts = df['Name'].value_counts()

if not message_counts.empty:
    most_talkative = message_counts.idxmax()
    least_talkative = message_counts.idxmin()

    print(f"Most talkative participant: {most_talkative} with {message_counts.max()} messages")
    print(f"Least talkative participant: {least_talkative} with {message_counts.min()} messages")
else:
    print("No messages found in the chat log.")
# Out:
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Most talkative participant:  AR❤ with 27 messages
# Least talkative participant:  Mabel Infoziant with 22 messages
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
import pandas as pd

# Assuming df is your DataFrame and it has 'Date' and 'Time' columns
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%y')

# Extract the day of the week
df['DayOfWeek'] = df['Date'].dt.day_name()

# Find the most active day (date)
most_active_day = df['Date'].value_counts().idxmax()

# Find the most active time
most_active_time = df['Time'].value_counts().idxmax()

# Find the most active day of the week
most_active_day_of_week = df['DayOfWeek'].value_counts().idxmax()

# Print the results
print(f"Most active date: {most_active_day.date()}")
print(f"Most active time: {most_active_time}")
print(f"Most active day of the week: {most_active_day_of_week}")
# Out:
# Most active date: 2019-12-05
# Most active time: 1:43 pm
# Most active day of the week: Thursday
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
import pandas as pd

# Assuming df is your DataFrame and it has 'Name' and 'Chat' columns

# Count media messages
media_counts = df[df['Chat'].str.contains('<Media omitted>', case=False, na=False)]['Name'].value_counts()

# Count video calls
video_call_counts = df[df['Chat'].str.contains('video call', case=False, na=False)]['Name'].value_counts()

# Count missed calls
missed_call_counts = df[df['Chat'].str.contains('missed call', case=False, na=False)]['Name'].value_counts()

# Count deleted media messages
deleted_media_counts = df[df['Chat'].str.contains('This message was deleted', case=False, na=False)]['Name'].value_counts()

# Print the results
print("Media counts by participant:")
print(media_counts)

print("\nVideo call counts by participant:")
print(video_call_counts)

print("\nMissed call counts by participant:")
print(missed_call_counts)

print("\nDeleted media counts by participant:")
print(deleted_media_counts)

# To get the total counts for each type, you can sum the counts if needed
total_media_count = media_counts.sum()
total_video_call_count = video_call_counts.sum()
total_missed_call_count = missed_call_counts.sum()
total_deleted_media_count = deleted_media_counts.sum()

print("\nTotal media count:", total_media_count)
print("Total video call count:", total_video_call_count)
print("Total missed call count:", total_missed_call_count)
print("Total deleted media count:", total_deleted_media_count)
# Out:
# Media counts by participant:
# Series([], Name: Name, dtype: int64)
#
# Video call counts by participant:
# Series([], Name: Name, dtype: int64)
#
# Missed call counts by participant:
# Series([], Name: Name, dtype: int64)
#
# Deleted media counts by participant:
# Series([], Name: Name, dtype: int64)
#
# Total media count: 0
# Total video call count: 0
# Total missed call count: 0
# Total deleted media count: 0

# %%
import pandas as pd

# Assuming df is your DataFrame and it has a 'Date' column

# Ensure the 'Date' column is in datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%y')

# Count the number of messages for each day
messages_per_day = df['Date'].value_counts()

# Calculate the average number of messages per day
average_messages_per_day = messages_per_day.mean()

# Print the average number of messages per day
print(f"Average number of messages per day: {average_messages_per_day:.2f}")
# Out:
# Average number of messages per day: 7.00
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Ensure the 'Date' column is in datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%y')

# Count the number of messages for each day
messages_per_day = df['Date'].dt.date.value_counts().sort_index()

# Convert to DataFrame
messages_per_day_df = messages_per_day.reset_index()
messages_per_day_df.columns = ['Date', 'Number of Messages']

# Plot the bar chart
plt.figure(figsize=(12, 6))
plt.bar(messages_per_day_df['Date'], messages_per_day_df['Number of Messages'])
plt.xlabel('Date')
plt.ylabel('Number of Messages')
plt.title('Number of Messages Per Day')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to fit labels
plt.show()
